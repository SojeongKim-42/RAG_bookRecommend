# %%
# %pip install -U langchain-core langchain-community
# Out:
# Requirement already satisfied: langchain-core in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (1.0.5)
# Collecting langchain-core
#   Downloading langchain_core-1.2.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: langchain-community in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (0.3.30)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-core) (0.4.32)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-core) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core)
#   Downloading uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.1 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.24.0)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.10.0)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=2.1.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from langchain-community) (2.3.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.19.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/bkms/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Downloading langchain_core-1.2.0-py3-none-any.whl (475 kB)
# Downloading uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (603 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.2/603.2 kB 17.4 MB/s  0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.9 MB/s  0:00:00 eta 0:00:01
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.7 MB/s  0:00:00
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Installing collected packages: uuid-utils, langchain-core, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.0.5
#     Uninstalling langchain-core-1.0.5:
#       Successfully uninstalled langchain-core-1.0.5
#   Attempting uninstall: langchain-text-splitters━━━━━━━━━━━━━━━━━━ 1/5 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.3.110m 1/5 [langchain-core]
#     Uninstalling langchain-text-splitters-0.3.11:━━━━━━━━━━━━━ 1/5 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.3.11 1/5 [langchain-core]
#   Attempting uninstall: langchain-community━━━━━━━━━━━━━━━ 3/5 [langchain-classic]
#     Found existing installation: langchain-community 0.3.30━━━ 3/5 [langchain-classic]
#     Uninstalling langchain-community-0.3.30:╺━━━━━━━ 4/5 [langchain-community]
#       Successfully uninstalled langchain-community-0.3.30━━━━━ 4/5 [langchain-community]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [langchain-community]ngchain-community]
# Successfully installed langchain-classic-1.0.0 langchain-community-0.4.1 langchain-core-1.2.0 langchain-text-splitters-1.0.0 uuid-utils-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.documents import Document
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = CSVLoader(
    file_path="./data/combined_preprocessed.csv",
    encoding="utf-8",
    csv_args={"delimiter": ","},
    content_columns=["구분", "상품명", "책소개", "목차"],
)
data = loader.load()

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=100
)
docs = text_splitter.split_documents(data)

# %%
print("\n--- Chunk 1 ---")
print(docs[0].page_content)
print("\n--- Chunk 2 ---")
print(docs[1].page_content)
print("\n--- Chunk 3 ---")
print(docs[2].page_content)
print("\n--- Chunk 4 ---")
print(docs[3].page_content)
# Out:
# --- Chunk 1 ---
# 구분: 대학교재/전문서적
# 상품명: 2026 간호사 국가고시 초단기완성 파이널 핵심요약집
# 책소개: 2026 간호사 국가고시 초단기완성 파이널 핵심요약집은 최근 13년 동안 출제되었던 간호사 국가고시 전 과목 기출문제를 전문가가 분석하여 문제 출제 경향을 반영한 핵심 개념을 수록했다. 단기간에 방대한 양을 효율적으로 공부할 수 있도록 표, 그림, 마인드맵을 수록하여 한눈에 쉽게 이해할 수 있도록 하였다. 간호사 국가고시 출제 경향을 한눈에 파악할 수 있도록 국가고시 시험에 실제 출제되었던 개념에 출제 연도를 표시하였다. 개정된 최신 출제 범위를 기준으로 수험생들이 꼭 학습해야 하는 시험에 필요한 내용만 수록하여 짧은 시간에 효율적으로 시험에 꼭 나오는 개념만 학습할 수 있도록 구성하였다.
# 목차: 1교시
# 1과목 성인간호학
# 1장 | 면역/신체손상
# 2장 | 안위변화
# 3장 | 섭취/흡수/대사장애
# 4장 | 체액불균형/배뇨장애
# 5장 | 활동/자기돌봄 장애
# 6장 | 심혈관/혈액 장애
# 7장 | 호흡기능장애
# 8장 | 인지/신경기능장애
# 9장 | 조절기능장애
# 10장 | 감각기능장애
#
# 2과목 모성간호학
# 1장 | 여성건강의 이해
# 2장 | 생애전환기 여성
# 3장 | 생식기 건강문제 여성
# 4장 | 임신기 여성
# 5장 | 분만기 여성
# 6장 | 산욕기 여성
# 7장 | 사회문화적 건강문제가 있는 여성
#
# 2교시
# 1과목 아동간호학
# 1장 | 아동 간호의 개념
# 2장 | 아동의 성장발달
# 3장 | 아동의 건강증진
# 4장 | 발달단계별 건강유지, 증진
# 5장 | 아동의 건강회복
#
# 2과목 지역사회간호학
# 1장 | 지역사회 건강요구 사정
# 2장 | 보건사업 기획 및 자원활용
# 3장 | 인구집단별 건강증진 및 유지
# 4장 | 안전과 환경관리
#
# 3과목 정신간호학
# 1장 | 정신건강
# 2장 | 정신건강 간호
# 3장 | 지역사회 정신건강
# 4장 | 정신질환 간호
#
# --- Chunk 2 ---
# 3과목 정신간호학
# 1장 | 정신건강
# 2장 | 정신건강 간호
# 3장 | 지역사회 정신건강
# 4장 | 정신질환 간호
#
# 3교시
# 1과목 간호관리학
# 1장 | 간호전문직의 이해
# 2장 | 기획
# 3장 | 조직
# 4장 | 인적자원관리
# 5장 | 지휘
# 6장 | 통제
# 7장 | 간호단위관리
# 2과목 기본간호학
# 1장 | 산소화 요구
# 2장 | 영양 요구
# 3장 | 배설 요구
# 4장 | 활동과 운동요구
# 5장 | 안위 요구
# 6장 | 안전 요구
# 7장 | 간호과정과 신체사정
# 3과목 보건의약관계법규
# 1장 | 의료법
# 2장 | 응급의료에 관한 법률(응급의료법)
# 3장 | 감염병의 예방 및 관리에 관한 법률(감염병예방법)
# 4장 | 후천성면역결핍증 예방법(에이즈예방법)
# 5장 | 검역법
# 6장 | 보건의료기본법
# 7장 | 지역보건법
# 8장 | 국민건강증진법
# 9장 | 국민건강보험법
# 10장 | 혈액관리법
# 11장 | 마약류 관리에 관한 법률(마약류관리법)
# 12장 | 호스피스완화의료 및 임종과정에 있는 환자의 연명의료결정에 관한 법률(연명의료결정법)
# 펼쳐보기
#
# --- Chunk 3 ---
# 구분: 대학교재/전문서적
# 상품명: 이기적 유전자
# 책소개: 과학을 넘어선 우리 시대의 고전, [이기적 유전자] 40주년 기념판
# 리처드 도킨스의 [새로운 에필로그] 수록
# 새로운 디자인으로 다시 태어난 세계적 베스트셀러
#
# 현대 생물학의 새로운 지평을 연 세계적인 석학 리처드 도킨스의 대표작 [이기적 유전자]의 40주년 기념판이 출간되었다. 진화론의 새로운 패러다임을 제시한 이 책은 다윈의 [적자생존과 자연선택]이라는 개념을 유전자 단위로 끌어내려 진화를 설명한다. 2013년 영국의 정치평론지 [프로스펙트]지가 독자들의 투표로 선정하는 [세계 최고의 지성] 1위에 오른 바 있는 도킨스는 일찍이 촉망받는 젊은 과학자로 간결한 문체와 생생한 비유, 논리적인 전개를 갖춘 글로 능력을 인정받아 왔다. 도킨스는 자신의 동물행동학 연구를 진화의 역사에서 유전자가 차지하는 중심적 역할에 대한 좀 더 넓은 이론적 맥락과 연결시키기 시작했는데, 그 결과가 바로 [이기적 유전자](초판 1976년, 개정판 1989년, 30주년 기념판 2006년, 40주년 기념판 2016년)다.
#
# [이기적 유전자]는 처음 출간되었을 당시 과학계와 일반 대중들에게 폭발적인 반향을 불러일으키며 세기의 문제작으로 떠올랐다. 혁신적인 통찰에 더해 사람의 마음을 휘어잡는 뛰어난 문장력과 명쾌한 구성력 또한 보여 주는 이 책은 명실상부 과학 교양서의 바이블로 일컬어지기에 손색이 없다. 또 최재천 이화여대 석좌교수가 [한 권의 책 때문에 인생관이 하루아침에 뒤바뀌는 경험을 한 적이 있는가? 내게는 [이기적 유전자]가 바로 그런 책이다]라고 말했던 것처럼, 이 책은 무엇보다 인간의 본질에 대한 근원적인 물음을 던지며 독자에게 큰 울림을 준다는 점에서 과학 책을 넘어 인생의 어느 지점에서 한 번쯤 읽어봐야 할 책으로 자리 잡았다. 이제 한국 독자들도 40년이라는 세월의 검증을 거치며 그 중요성과 깊이를 더욱더 확고하게 인정받은 [이기적 유전자]의 최신 판본을 만나볼 수 있게 되었다.
#
# --- Chunk 4 ---
# 이번 40주년 기념판에 새롭게 수록된 에필로그에서 도킨스는 여전히 [이기적 유전자]라는 개념이 갖고 있는 지속적인 타당성을 이야기하며 이 책이 전하는 메시지를 되새긴다. 새로운 에필로그를 수록하는 것은 물론 새로운 디자인과 휴대하기 좋은 판형으로 갈아입은 40주년 기념판을 통해 독자들은 [이기적 유전자]가 주는 울림을 더욱더 선명하게 느낄 수 있을 것이다.
#
#
#
#  책의 일부 내용을 미리 읽어보실 수 있습니다.
# 목차: 옮긴이의 말
# 30주년 기념판 서문
# 개정판 서문
# 초판 권두사
# 초판 서문
#
# 1장. 사람은 왜 존재하는가?
# 진화 - 가장 근본적 질문에 대한 대답
# 이기주의와 이타주의
# 집단선택설
#
# 2장. 자기 복제자
# 안정을 향하여
# 생명의 기원과 자기 복제자
#
#
# 유전자란 무엇인가
# 유성생식과 유전자의 정의
# 불멸의 유전자
# 노화 이론
#
#
# 생존 기계의 시작
# 동물의 행동
# 시뮬레이션
# 의사소통
#
#
# 다른 생존 기계는 환경의 일부
# 게임 이론과 진화적으로 안정한 전략
# 비대칭적 싸움
#
#
# 이기적 유전자와 이타주의
# 혈연선택
# 부모와 자식의 관계
#
#
# 아이 낳기와 아이 키우기
# 개체 수 조절과 인구 문제
# 가족계획 이론
#
#
# 가족 내부의 이해관계
# 갈등의 승자
#
#
# 짝 간의 갈등
# 성의 전략
# 이기적인 기계 - 누가 누구를 착취할 것인가?
# 암컷의 선택
# 암컷은 좋은 유전자를 찾는다
# 암수의 차이
# 인간에서의 성선택
#
#
# 집단 형성이 주는 이익
# 사회성 곤충
# 협력의 진화
#
#
# 문화, 문화적 돌연변이
# [밈]과 그 진화
# 밈의 특성
#
#
# 마음씨 좋은 놈, 마음씨 나쁜 놈
# 죄수의 딜레마
# 영합 게임과 비영합 게임
#
#
# 유전자냐 개체냐
# 기생자와 숙주
# 유전자냐 개체냐
#
# 40주년 기념판 에필로그
# 보주
# 참고 문헌
# 찾아보기
# 이 책에 대한 서평
# 펼쳐보기
